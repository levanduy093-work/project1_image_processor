# %%
# Import nessesary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read image
image_path = 'raw_image/robert_raw.png'

# Matrix to store the result
image = cv2.imread(image_path)
image
# Out:
# array([[[ 23,  11,   0],
#         [ 23,  11,   0],
#         [ 23,  11,   0],
#         ...,
#         [  9,  16,   9],
#         [  9,  16,   9],
#         [  8,  15,   8]],
#
#        [[ 55,  41,  23],
#         [ 53,  42,  22],
#         [ 55,  41,  23],
#         ...,
#         [115, 122, 115],
#         [114, 121, 114],
#         [113, 120, 113]],
#
#        [[ 54,  39,  20],
#         [ 53,  40,  18],
#         [ 54,  39,  20],
#         ...,
#         [109, 116, 109],
#         [108, 115, 108],
#         [108, 115, 108]],
#
#        ...,
#
#        [[ 26,  23,  19],
#         [ 26,  23,  19],
#         [ 26,  23,  19],
#         ...,
#         [ 22,  19,  15],
#         [ 22,  19,  15],
#         [ 22,  19,  15]],
#
#        [[ 41,  38,  34],
#         [ 41,  38,  34],
#         [ 41,  38,  34],
#         ...,
#         [ 33,  30,  26],
#         [ 33,  30,  26],
#         [ 33,  30,  26]],
#
#        [[  9,   5,   4],
#         [  9,   5,   4],
#         [  9,   5,   4],
#         ...,
#         [  8,   4,   3],
#         [  8,   4,   3],
#         [  8,   4,   3]]], dtype=uint8)

# %%
# Image size
image.shape
# Out:
# (1001, 564, 3)

# %%
# high, width, channel
h , w, c = image.shape
print("Height: ", h, ", Width: ", w, ", Channel: ", c)
# Out:
# Height:  1001 , Width:  564 , Channel:  3

# %%
image.size
# Out:
# 1693692

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(image)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
