# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Checkered Board
#Bàn cờ có cạnh là 8 ô, mỗi ô là 50 điểm ảnh
square = 50
board = 8

#Viết hàm điền màu trắng cho các ô
def create_chessboard(board=8, square=50):
    chessboard = np.zeros((board*square,board*square),dtype=np.uint8)
    for row in range(board):
        for col in range(board):
            if((row+col)%2==0):
                chessboard[row*square : (row+1)*square,
                           col*square : (col+1)*square] = 255
                
    return chessboard

#Tạo ma trận bàn cờ
chessboard = create_chessboard(board,square)
chessboard
# Out:
# array([[255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(chessboard, cmap='gray')

# %%
#Color Correction
#Ảnh mẫu
img_2_filename = 'lion.jpg'
img_2 = cv2.imread(img_2_filename)
plt.imshow(img_2[:,:,::-1])

# %%
#Chuyển màu
img_2_gray = img_2[:,:,0]*0.07 + img_2[:,:,1]*0.72 + img_2[:,:,2]*0.21
plt.imshow(img_2_gray,cmap='gray')

# %%
img_2_gray = cv2.imread(img_2_filename,0)
plt.imshow(img_2_gray,cmap='gray')

# %%
#Rotate Image
#Ảnh gốc
img_3_filename = 'cat.jpg'
img_3 = cv2.imread('cat.jpg')
plt.imshow(img_3[:,:,::-1])

# %%
#Hàm xoay hình theo trục thẳng đứng
def rotate_img(img):
    h,w,c = img.shape
    r_img = np.zeros_like(img_3)
    for i in range(w):
        r_img[:,i,:] = img[:,w-1-i,:]
    return r_img

# %%
r_img = rotate_img(img_3)
plt.imshow(r_img)

# %%
#Color Separation

# %%
#Corner line

# %%
#Gradient
#Tạo một mảng 2 chiều với kích thước 256x256
img_arr = np.zeros((256,256),dtype=np.uint8)
img_arr.shape
#Viết hàm thay đổi sắc độ từ trên xuống dưới
def Gradient_down(img):
    g_img = img.copy()
    h,w = img_arr.shape
    for i in range(h):
        g_img[i,:] = 255-i
    return g_img
g_img = Gradient_down(img_arr)
plt.imshow(g_img, cmap='gray')

# %%
#Viết hàm thay đổi sắc độ từ trên dưới lên trên
def Gradient_up(img):
    g_img = img.copy()
    h,w = img_arr.shape
    for i in range(h):
        g_img[i,:] = 0+i
    return g_img
g_img = Gradient_up(img_arr)
plt.imshow(g_img, cmap='gray')

# %%
#Letter B
#Tạo ma trận 2 chiều
b_img = np.zeros((300,300),dtype=np.uint8)
def letterB(img):
    l_img = img.copy
    h,w = img.shape
    for i in range(w):
        

plt.imshow(b_img,cmap='gray')
